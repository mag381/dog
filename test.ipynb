# %% [markdown]
# <a href="https://colab.research.google.com/github/mag381/dog/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# test

# %%
from google.colab import files
uploaded_file = files.upload()
# Out:
#      <input type="file" id="files-62dc1d2e-4800-45db-b9c4-fbc653f4ae7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62dc1d2e-4800-45db-b9c4-fbc653f4ae7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving face-mona.jpg to face-mona.jpg

# %%
uploaded_file_name = next(iter(uploaded_file))
print(uploaded_file_name)
# Out:
# face-mona.jpg

# %%
import cv2

orig = cv2.imread(uploaded_file_name)
src = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt
plt.axis('off')
plt.imshow(src)

# %%
import numpy as np

pixels = np.array(src)
pixels = np.array(src, dtype = 'float32')
pixels = np.clip(pixels *1.5, 0., 255.)
plt.imshow(pixels.astype('uint8'))
