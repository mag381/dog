# %% [markdown]
# <a href="https://colab.research.google.com/github/mag381/dog/blob/main/Panda_01_usdjpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas_datareader.data as web
usdjpy = web.DataReader('DEXJPUS', 'fred', start='2022-01-01')
usdjpy.tail
# Out:
# <bound method NDFrame.tail of             DEXJPUS
# DATE
# 2022-01-03   115.27
# 2022-01-04   116.12
# 2022-01-05   115.91
# 2022-01-06   115.78
# 2022-01-07   115.61
# ...             ...
# 2022-06-20      NaN
# 2022-06-21   136.25
# 2022-06-22   136.05
# 2022-06-23   134.72
# 2022-06-24   135.22
#
# [125 rows x 1 columns]>

# %%
usdjpy.plot();
