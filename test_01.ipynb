# %% [markdown]
# <a href="https://colab.research.google.com/github/mag381/dog/blob/main/test_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **test_01.ipynb**

# %%
import cv2

# %%
# !wget -q https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_alt.xml
cascade = cv2.CascadeClassifier('./haarcascade_frontalface_alt.xml')

# %%
from google.colab import files
uploaded_file = files.upload()
uploaded_file_name = next(iter(uploaded_file))

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(10,10))

image = cv2.imread(uploaded_file_name)
image = image[:, :, ::-1]
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
image = cv2.imread(uploaded_file_name)
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
facerect = cascade.detectMultiScale(image_gray, scaleFactor=1.1, minNeighbors=1, minSize=(1, 1))
print(facerect)
if len(facerect) > 0:
  for rect in facerect:
    cv2.rectangle(image, tuple(rect[0:2]),tuple(rect[0:2]+rect[2:4]), (255, 255, 255), thickness=2)
fig = plt.figure(figsize=(10,10))
image = image[:, :, ::-1]
plt.imshow(image)
plt.axis('off')
plt.show()
